# %% [markdown]
# <a href="https://www.kaggle.com/code/denizherand/phyton-al-t-rmalar?scriptVersionId=194283310" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# GÖREV 1: Veri yapılarının tipleriniz inceleyiniz.

# %%
x = 8
print(type(x))
# Out:
# <class 'int'>
